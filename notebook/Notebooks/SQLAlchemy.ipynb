# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("iris://_SYSTEM:SYS@resttodicom:1972/RESTTODICOM")

# %%
pd.read_sql("select * from AA.Observation",engine)
# Out:
#     ID CodeCodingCode CodeCodingDisplay  CodeCodingSystem             Key  \
# 0    2         8302-2       Body height  http://loinc.org   Observation/2
# 1    4         8302-2       Body height  http://loinc.org   Observation/4
# 2    6         8302-2       Body height  http://loinc.org   Observation/6
# 3    9         8302-2       Body height  http://loinc.org   Observation/9
# 4   11         8302-2       Body height  http://loinc.org  Observation/11
# 5   12         8302-2       Body height  http://loinc.org  Observation/12
# 6   13         8302-2       Body height  http://loinc.org  Observation/13
# 7   14         8302-2       Body height  http://loinc.org  Observation/14
# 8   15         8302-2       Body height  http://loinc.org  Observation/15
# 9   16         8302-2       Body height  http://loinc.org  Observation/16
# 10  17         8302-2       Body height  http://loinc.org  Observation/17
# 11  18         8302-2       Body height  http://loinc.org  Observation/18
# 12  19         8302-2       Body height  http://loinc.org  Observation/19
# 13  21         8302-2       Body height  http://loinc.org  Observation/21
#
#    SubjectReference ValueQuantityCode        ValueQuantitySystem  \
# 0         Patient/0                cm  http://unitsofmeasure.org
# 1         Patient/8                cm  http://unitsofmeasure.org
# 2         Patient/4                cm  http://unitsofmeasure.org
# 3         Patient/7                cm  http://unitsofmeasure.org
# 4         Patient/5                cm  http://unitsofmeasure.org
# 5         Patient/5                cm  http://unitsofmeasure.org
# 6         Patient/7                cm  http://unitsofmeasure.org
# 7         Patient/5                cm  http://unitsofmeasure.org
# 8         Patient/0                cm  http://unitsofmeasure.org
# 9         Patient/5                cm  http://unitsofmeasure.org
# 10        Patient/5                cm  http://unitsofmeasure.org
# 11        Patient/8                cm  http://unitsofmeasure.org
# 12        Patient/0                cm  http://unitsofmeasure.org
# 13        Patient/9                cm  http://unitsofmeasure.org
#
#    ValueQuantityUnit  ValueQuantityValue
# 0                 cm                  76
# 1                 cm                  22
# 2                 cm                  74
# 3                 cm                  85
# 4                 cm                 180
# 5                 cm                  24
# 6                 cm                  54
# 7                 cm                 143
# 8                 cm                  90
# 9                 cm                 128
# 10                cm                   7
# 11                cm                  50
# 12                cm                 170
# 13                cm                 128
